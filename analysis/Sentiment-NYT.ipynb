# %%
# %cd ../
# Out:
# /Users/toz/Documents/workspace/Circle-of-Doom

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/all-sentipol.csv')
df = df[df.src=='NYT']
print('fields:',', '.join(df.columns.values))
# Out:
# fields: cat, dt, fav, href, newstxt, spnews, rt, src, title, tweep, twtext, url, sptw, sptitle

# %%
df.corr() # rt,spnews (sentiment-polarity-of-news) correlation is 0.021
# Out:
#               fav    spnews        rt      sptw   sptitle
# fav      1.000000  0.064432  0.744023  0.021380  0.035170
# spnews   0.064432  1.000000  0.021626  0.095070  0.085840
# rt       0.744023  0.021626  1.000000 -0.006829 -0.003292
# sptw     0.021380  0.095070 -0.006829  1.000000  0.492861
# sptitle  0.035170  0.085840 -0.003292  0.492861  1.000000

# %%
# RT vs polarity
df.plot(x='rt',y='spnews',kind='scatter')

# %%
#let's zoom in...
df.plot(x='rt',y='spnews',kind='scatter',xlim=(0,1000),ylim=(-.5,.5))

# %%
# Most RTed tweets info...
df.sort(columns='rt',ascending=False).head()
# Out:
#        cat                   dt   fav  \
# 1112  news  2015-02-27 12:10:06  1411
# 1171  news  2015-02-27 05:01:19  2826
# 174   news  2015-02-19 03:27:19  1623
# 1239  news  2015-02-27 05:01:19  2157
# 432   news  2015-02-19 03:27:19  2067
#
#                                                    href  \
# 1112  http://www.nytimes.com/2015/02/27/arts/televis...
# 1171  http://www.nytimes.com/2015/02/28/science/nant...
# 174   http://www.nytimes.com/2015/02/19/opinion/oliv...
# 1239  http://www.nytimes.com/2015/02/28/science/nant...
# 432   http://www.nytimes.com/2015/02/19/opinion/oliv...
#
#                                                 newstxt    spnews    rt  src  \
# 1112  Leonard Nimoy, the sonorous, gaunt-faced actor...  0.090528  8917  NYT
# 1171  How cold has it been on Nantucket? Chilly enou... -0.036176  2853  NYT
# 174   A MONTH ago, I felt that I was in good health,...  0.191340  2490  NYT
# 1239  How cold has it been on Nantucket? Chilly enou... -0.036176  2267  NYT
# 432   A MONTH ago, I felt that I was in good health,...  0.191340  2103  NYT
#
#                                                   title       tweep  \
# 1112  Leonard Nimoy, Spock of ‘Star Trek,’ Dies at 8...     nytimes
# 1171  On Nantucket, Surf’s Up, if You’re Part Pengui...     nytimes
# 174   Oliver Sacks on Learning He Has Terminal Cance...  nytopinion
# 1239  On Nantucket, Surf’s Up, if You’re Part Pengui...     nytimes
# 432   Oliver Sacks on Learning He Has Terminal Cance...     nytimes
#
#                                                  twtext  \
# 1112  Breaking News: Leonard Nimoy, Spock of ‘Star T...
# 1171  Cold enough to freeze the waves http://t.co/zV...
# 174   Oliver Sacks on learning he has terminal cance...
# 1239  Cold enough to freeze the waves http://t.co/v1...
# 432   Oliver Sacks on learning he has terminal cance...
#
#                          url  sptw  sptitle
# 1112  http://nyti.ms/1DzHhyw   0.0        0
# 1171  http://nyti.ms/1Bo1Y11  -0.3        0
# 174   http://nyti.ms/1G7xal0   0.0        0
# 1239  http://nyti.ms/1DBEXXM  -0.3        0
# 432   http://nyti.ms/17k7oy1   0.0        0

# %%
# fav vs polarity
df.plot(x='fav',y='spnews',kind='scatter')

# %%
#let's zoom in...
df.plot(x='fav',y='spnews',kind='scatter',xlim=(0,1000),ylim=(-.5,.5))

# %%
# rt vs fav
df.plot(x='rt',y='fav',kind='scatter',xlim=(0,1000),ylim=(0,1000))

# %%
# let's "kind of" replicate the graph in the social deviance study
# first get quantiles based on RTs
rt = df.sort('rt',ascending=False).dropna()

# %%
def quantile_list(df, quantiles):
     return type(df)({q: df.quantile(q) for q in quantiles})
     # this will work for both Series and DataFrames
        
quantile_list(rt, np.arange(0,1,0.2))
# Out:
#                0.0        0.2        0.4         0.6         0.8
# fav      15.000000  44.000000  61.000000   88.000000  160.000000
# spnews   -0.153846   0.034808   0.069117    0.094954    0.126595
# rt       10.000000  47.000000  71.000000  107.000000  178.000000
# sptw     -1.000000   0.000000   0.000000    0.000000    0.136364
# sptitle  -0.875000   0.000000   0.000000    0.000000    0.100000

# %%
# polarity values for quintiles averaged...
#let's get the quantiles for RTs
rts = quantile_list(rt, np.arange(0,1,0.2)).ix['rt'].values.tolist() + [rt.rt.max()]
y = []
for q in range(len(rts)-1):
    print(str('Q'+str(q+1)),': {0:7.2f} - {1:7.2f}'.format(rts[q],rts[q+1]), sep=' ',end='\t')
    y.append(df[(rts[q] <= df['rt']) & (df['rt'] < rts[q+1])].spnews.mean())
    print('Sentiment polarity of news (mean):{0:5.2f}'.format(y[-1]))
# Out:
# Q1 :   10.00 -   47.00	Sentiment polarity of news (mean): 0.07
# Q2 :   47.00 -   71.00	Sentiment polarity of news (mean): 0.07
# Q3 :   71.00 -  107.00	Sentiment polarity of news (mean): 0.06
# Q4 :  107.00 -  178.00	Sentiment polarity of news (mean): 0.06
# Q5 :  178.00 - 8917.00	Sentiment polarity of news (mean): 0.07

# %%
plt.barh(range(5),y)
plt.xlabel('Sentiment Polarity')
plt.ylabel('RT Quintiles (Q5 is top, Q1 is botttom)')
plt.title('Mean of polarities accross quintiles')
plt.yticks(np.arange(5) + 0.35, ('Q1', 'Q2', 'Q3', 'Q4', 'Q5'));

# %%
df.mean()
# Out:
# fav        123.124340
# spnews       0.067271
# rt         139.756197
# sptw         0.049179
# sptitle      0.040644
# dtype: float64

# %%
# %cd ../
# Out:
# C:\Users\Talha\Documents\WinPython3\projects\cnnyt

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv('data/all-sentipol.csv')
df = df[df.src=='CNN']
print('Header:',', '.join(df.columns.values))
print('Number of rows and columns:',df.shape)
# Out:
# Header: cat, dt, fav, href, newstxt, spnews, rt, src, title, tweep, twtext, url, sptw, sptitle
# Number of rows and columns: (1926, 14)

# %%
df.corr() # rt,spnews (sentiment-polarity-of-news) correlation is 0.021
# Out:
#               fav    spnews        rt      sptw   sptitle
# fav      1.000000  0.092744  0.838633  0.092016  0.068464
# spnews   0.092744  1.000000  0.021429  0.265217  0.269133
# rt       0.838633  0.021429  1.000000  0.025739 -0.015932
# sptw     0.092016  0.265217  0.025739  1.000000  0.393842
# sptitle  0.068464  0.269133 -0.015932  0.393842  1.000000

# %%
# RT vs polarity
df.plot(x='rt',y='spnews',kind='scatter')

# %%
#let's zoom in...
df.plot(x='rt',y='spnews',kind='scatter',xlim=(0,1000),ylim=(-.5,.5))

# %%
# Most RTed tweets info...
df.sort(columns='rt',ascending=False).head()
# Out:
#         cat                   dt   fav  \
# 3373   news  2015-02-11 23:30:00  1823
# 3289   news  2015-02-09 07:42:00  4746
# 2622   news  2015-01-23 02:18:00  1115
# 4347   news  2015-03-10 13:15:00  4078
# 3440  money  2015-02-12 05:41:53  2581
#
#                                                    href  \
# 3373  http://www.cnn.com/2015/02/11/us/chapel-hill-s...
# 3289  http://www.cnn.com/2015/02/09/entertainment/fe...
# 2622  http://www.cnn.com/2015/01/22/middleeast/saudi...
# 4347  http://www.cnn.com/2015/03/10/living/feat-zool...
# 3440  http://money.cnn.com/2015/02/12/news/economy/c...
#
#                                                 newstxt    spnews    rt  src  \
# 3373   (CNN)Was it a dispute over a parking space or...  0.033372  7752  CNN
# 3289   (The Hollywood Reporter)According to Kanye We...  0.151218  7139  CNN
# 2622   (CNN)Throngs of mourners gathered in Mecca ea...  0.150590  4561  CNN
# 4347   (CNN)Everyone's favorite male models made a s...  0.130985  4270  CNN
# 3440  It's been a year since Colorado became the fir...  0.141496  4116  CNN
#
#                                                   title   tweep  \
# 3373  3 students killed in Chapel Hill shooting - CN...     cnn
# 3289  Grammys: Kanye rants "Beck needs to respect ar...     cnn
# 2622        Saudi Arabia's King Abdullah dies - CNN.com  cnnbrk
# 4347  Zoolander and Hansel walk runway at Paris Fash...     cnn
# 3440  Recreational pot delivers $53 million in tax r...     cnn
#
#                                                  twtext  \
# 3373  A man has been charged w/murder in the shootin...
# 3289  .@kanyewest says he wasn't  joking when he nea...
# 2622  Saudi Arabia’s King Abdullah bin Abdulaziz al ...
# 4347  Derek Zoolander and Hansel make a surprise app...
# 3440  Colorado has made $53 million in tax revenue f...
#
#                         url  sptw  sptitle
# 3373  http://cnn.it/1KIjKP9   0.0     -0.2
# 3289  http://cnn.it/1zAZPxX   0.1      0.0
# 2622  http://cnn.it/1t3xpeS   0.0      0.0
# 4347  http://cnn.it/1MoDENZ   0.0      0.0
# 3440  http://cnn.it/1716DJX   0.0      0.0

# %%
# fav vs polarity
df.plot(x='fav',y='spnews',kind='scatter')

# %%
#let's zoom in...
df.plot(x='fav',y='spnews',kind='scatter',xlim=(0,1000),ylim=(-.5,.5))

# %%
# rt vs fav
df.plot(x='rt',y='fav',kind='scatter',xlim=(0,1000),ylim=(0,1000))

# %%
# let's "kind of" replicate the graph in the social deviance study
# first get quantiles based on RTs
rt = df.sort('rt',ascending=False).dropna()

# %%
def quantile_list(df, quantiles):
     return type(df)({q: df.quantile(q) for q in quantiles})
     # this will work for both Series and DataFrames
        
quantile_list(rt, np.arange(0,1,0.2))
# Out:
#             0.0  0.2         0.4        0.6         0.8
# fav      16.000   81  130.000000  222.00000  430.800000
# spnews   -0.875    0    0.048458    0.08814    0.144675
# rt       10.000   93  163.000000  283.60000  503.800000
# sptw     -1.000    0    0.000000    0.00000    0.200000
# sptitle  -1.000    0    0.000000    0.00000    0.068182

# %%
# polarity values for quintiles averaged...
#let's get the quantiles for RTs
rts = quantile_list(rt, np.arange(0,1,0.2)).ix['rt'].values.tolist() + [rt.rt.max()]
y = []
for q in range(len(rts)-1):
    print(str('Q'+str(q+1)),': {0:7.2f} - {1:7.2f}'.format(rts[q],rts[q+1]), sep=' ',end='\t')
    quintile = df[(rts[q] <= df['rt']) & (df['rt'] < rts[q+1])]
    # qmean = quintile.spnews.mean()
    # weight = np.sum(quintile.spnews * quintile.rt)*100/quintile.rt.sum()
    median = quintile[quintile.spnews > df.spnews.median()].rt.sum() *100 / quintile.rt.sum()
    # mean =  quintile[quintile.spnews > df.spnews.mean()].rt.sum() *100 / quintile.rt.sum()
    y.append(median)
    print('RT weighted sentiment polarity of news:{0:5.2f}'.format(y[-1]))
# Out:
# Q1 :   10.00 -   93.00	RT weighted sentiment polarity of news:49.96
# Q2 :   93.00 -  163.00	RT weighted sentiment polarity of news:47.66
# Q3 :  163.00 -  283.60	RT weighted sentiment polarity of news:51.35
# Q4 :  283.60 -  503.80	RT weighted sentiment polarity of news:47.67
# Q5 :  503.80 - 7752.00	RT weighted sentiment polarity of news:55.52

# %%
plt.barh(range(5),y)
plt.xlabel('Sentiment Polarity')
plt.ylabel('RT Quintiles (Q5 is top, Q1 is botttom)')
plt.title('Mean of polarities accross quintiles')
plt.yticks(np.arange(5) + 0.35, ('Q1', 'Q2', 'Q3', 'Q4', 'Q5'));

# %%
df.mean()
# Out:
# fav        292.074247
# spnews       0.070329
# rt         362.209242
# sptw         0.061108
# sptitle      0.030199
# dtype: float64
